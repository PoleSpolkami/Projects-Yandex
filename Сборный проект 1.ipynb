# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Полина :)  Спасибо за работу, все исправления и комментарии
#
# На проекте мы изучали и практиковали навыки из разделов о/об:
#
#  + выдвижении гипотез о пропусках в данных, заполнении или удалении,
#  + работе с категориальными данными
#  + подготовке данных для решения главной задачи проекта
#  + исследовании неочищенных данных,
#  + подборе и создании графиков,
#  + программировании,
#  + автоматизации однотипных действий,
#  + выстраивании структуры проекта и обеспечении аккуратности кода,
#  + анализе данных,
#  + определении прибыльности и устойчивости продаж по выбранному параметру (жанр, платформа) на диаграмме размаха,
#  + составлении портрета пользователя,
#  + формулировании и проверке двухсторонних гипотез, интерпретации значения p-value
#  + формировании рекомендаций для бизнеса
#
# <b>Навыки первого модуля освоены хорошо</b>
#
# <b>Поздравляю с успешно сданным сборным проектом и завершением первого модуля <br />на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />
#
# добавил бонус

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Привет, Полина :) Спасибо за доработки
#
# Критические ❌ комментарии:
#
#  + поправить расчет при создании выборки в подразделе портретов из ТОП-5 и категории «другие»
#
# подсказку добавил

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Привет, Полина :) Спасибо за доработки
#
# Критические ❌ комментарии:
#
#  + создать выборку в подразделе портретов из ТОП-5 и категории «другие»
#  + в разделе проверки гипотез подправить выборки
#
# подсказки добавил

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Полина :) Спасибо, что прислала задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://devpractice.ru/matplotlib-book/">“Библиотека Matplotlib” доступна для скачивания БЕСПЛАТНО!</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет), если что буду ставить ✔️ там, где думаю что обработала комментарии, чтобы не запутаться при исправлении.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />принимается

# %% [markdown]
# # Исследование данных для интернет-магазина "Стримчик"
#
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.

# %% [markdown]
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# **Цели исследования:**
# * Проанализировать данные
# * Проверить гипотезы
# * Предобработать данные
# * Составить портрет пользователя каждого региона
#
#
#
# **Таким образом, исследование пройдёт в шесть этапов:**
# 1. Загрузка данных
# 2. Предобработка данных
# 3. Исследовательский анализ данных
# 4. Составить портрет каждого пользователя по регионам
# 5. Проверка гипотез
# 6. Общий вывод

# %% [markdown]
# ### Загрузка данных

# %% [markdown]
# #### 1.1 Откройте файл с данными

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from scipy import stats as st

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Молодец, что делишь блоки загрузки библиотек и датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %%
try:
    
    df = pd.read_csv('games.csv')
    
except:
    
    df = pd.read_csv('/datasets/games.csv')

# %% [markdown]
# #### 1.2  Изучите общую информацию

# %%
df.head(15)
# Out:
#                            Name Platform  Year_of_Release         Genre  \
# 0                    Wii Sports      Wii           2006.0        Sports
# 1             Super Mario Bros.      NES           1985.0      Platform
# 2                Mario Kart Wii      Wii           2008.0        Racing
# 3             Wii Sports Resort      Wii           2009.0        Sports
# 4      Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                        Tetris       GB           1989.0        Puzzle
# 6         New Super Mario Bros.       DS           2006.0      Platform
# 7                      Wii Play      Wii           2006.0          Misc
# 8     New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                     Duck Hunt      NES           1984.0       Shooter
# 10                   Nintendogs       DS           2005.0    Simulation
# 11                Mario Kart DS       DS           2005.0        Racing
# ...

# %% [markdown]
# *Посмотрим на количество пропущенных значений*

# %%
df.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64

# %% [markdown]
# *Посмотрим на количество явных дубликатов*

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Проверка на поиск дубликатов выполнена, молодец
#
# Особенно это станет важным, когда мы перейдем к более сложным задачам на втором модуле курса

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font> ✔️
#     <br />
#     <font size="3", color = "black">
# <br />
# На рабочих проектах стоит искать дубликаты по ключевым столбцам, для примера по сумме параметров:
#
#     ['name', 'platform', 'year_of_release']
#
# С обязательным приведением содержимого категориальных колонок к нижнему регистру
#
# В сырой выборке имеется 2 строчки неполных дубликатов
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html?highlight=duplicat#pandas.DataFrame.duplicated
#
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Сделала это в пункте 2.4, надеюсь поняла верно

# %% [markdown]
# *Посмотрим н количество неявных дубликатов в некоторых столбцах*

# %%
display(df['Name'].unique())
display(df['Platform'].unique())
display(df['Genre'].unique())
display(df['Critic_Score'].unique())
display(df['User_Score'].unique())
display(df['Rating'].unique())
# Out:
# array(['Wii Sports', 'Super Mario Bros.', 'Mario Kart Wii', ...,
#        'Woody Woodpecker in Crazy Castle 5', 'LMA Manager 2007',
#        'Haitaka no Psychedelica'], dtype=object)
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy', nan], dtype=object)
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# #### *** Описание данных:***
#
# **Name** — название игры
#
# **Platform** — платформа
#
# **Year_of_Release** — год выпуска
#
# **Genre** — жанр игры
#
# **NA_sales** — продажи в Северной Америке (миллионы проданных копий)
#
# **EU_sales** — продажи в Европе (миллионы проданных копий)
#
# **JP_sales** — продажи в Японии (миллионы проданных копий)
#
# **Other_sales** — продажи в других странах (миллионы проданных копий)
#
# **Critic_Score** — оценка критиков (максимум 100)
#
# **User_Score** — оценка пользователей (максимум 10)
#
# **Rating** — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.

# %% [markdown]
# **Вывод:**
#
# Изучили датафрейм и информацию о нем, всего имеем 16715 записей. В данных присутсвуют пропуски, обнаружены неявные дубликаты в некоторых столбцах, названия столбцов написаны в разных регистрах, так же тип данных некоторых колонок неверен, явные дубликаты отсутсвуют.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> загрузка и обзор данных проведены корректно

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 20)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(df)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста
#
# мой график оформлен не совсем корректно, сможешь отметить, что стоило бы исправить в графике?
#
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Возможно то что в графике не подписаны оси для удобства восприятия, деления на оси расположены далеко друг от друга, нет точности понимания сколько именно пропусков.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# За поворот текста отвечает параметр rot, можно добавить обозначение оси х (процент записей с пропусками)
#
#         df.isna().mean()*100 — для расчета процента пропусков в колонке
#
# На графике мы оцениваем масштаб проблемы с пропусками и возможное совпадение % пропущенных значений в колонках

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Изменение названия столбцов

# %% [markdown]
# *Приведем все столбцы датафрейма к нижнему регистру, а так же удалим неполные дубликаты*

# %%
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# *Изменение прошло успешно*

# %% [markdown]
# #### Переобразование типа данных

# %% [markdown]
# *Заменим тип данных в столбце year_of_release, так как года записываются целыми числами, но сделаем это после заполнения пропусков*

# %% [markdown]
# *Так же требуется заменить тип данных в столбце user_score так как в нем содержатся оценки, но для этого изначально нужно разобраться со значением tbd. TBD - аббревиатура от английского To Be Determined (будет определено). Заменим такие значения на NaN*

# %%
df.loc[df['user_score'] == 'tbd', 'user_score'] = np.nan

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Верно, по своей сути tbd и является Nan. Отлично, что определяешь неявные пропущенные значения.

# %%
df['user_score'] = df['user_score'].astype('float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: float64(7), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# *Типы данных изменились верно*

# %% [markdown]
# *Если посмотреть на неявные дубликаты столбца rating можно заметить 2 значения K-A и E. «E» («Everyone») — "Для всех", у которого первоначальное значение "K-A" ("Kids to Adults"), переименуем для более точного анализа"*

# %%
df['rating'] = df['rating'].str.replace('K-A','E')
df['rating'].value_counts()
# Out:
# E       3993
# T       2961
# M       1563
# E10+    1420
# EC         8
# RP         3
# AO         1
# Name: rating, dtype: int64

# %% [markdown]
# *Замена прошла успешно*

# %% [markdown]
# #### Обработка пропусков

# %% [markdown]
# *Посомтрим снова на количество пропусков*

# %%
df.isna().sum().sum()
# Out:
# 24742

# %%
df.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         9125
# rating             6766
# dtype: int64

# %% [markdown]
# *Всего имеем 24742 пропусков в 6 столбцах*
#
# *name* **2** Пропусков мало, скорее всего не указали данные, возможности восполнить нет, <u>удалим пропуски</u>
#
# *year_of_release* **269** Пропусков немного. Возможно они появились из-за ошибки при вводе данных или отсутствие информации о точном годе выпуска, данные восполнить нечем, удалим <u>пропуски</u>
#
# *genre* **2** Пропусков мало, скорее всего не указали данные, возможности восполнить нет, <u>удалим пропуски</u>
#
# *critic_score* **8578** Возможно это игры которые просто не получили оценки, либо недооценённые игры либо недавно вышедшие. Данные важны, но восполнить их нечем <u>оставим пропуски</u>
#
# *user_score* **9125** Возможно это игры которые просто не получили оценки, либо недооценённые игры либо недавно вышедшие. Данные важны, но восполнить их нечем <u>оставим пропуски</u>
#
# *rating* **6766** Пропусков много, данные важны для исследования, <u>заменим их</u> на undefined(неопределено)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />плюс отсутствие ресурсов на сбор информации (время, деньги)

# %% [markdown]
# *Пропуски в столбце name и genre*(тк пропуски находились в двух строках)

# %%
df.dropna(subset = ['name'],inplace=True)

# %% [markdown]
# *Пропуски и замена типа в столбце year_of_release*

# %%
display(df[df["year_of_release"].isna()])
# Out:
#                                     name platform  year_of_release  \
# 183                      Madden NFL 2004      PS2              NaN
# 377                     FIFA Soccer 2004      PS2              NaN
# 456           LEGO Batman: The Videogame      Wii              NaN
# 475           wwe Smackdown vs. Raw 2006      PS2              NaN
# 609                       Space Invaders     2600              NaN
# ...                                  ...      ...              ...
# 16373  PDC World Championship Darts 2008      PSP              NaN
# 16405                      Freaky Flyers       GC              NaN
# 16448                          Inversion       PC              NaN
# 16458        Hakuouki: Shinsengumi Kitan      PS3              NaN
# 16522                       Virtua Quest       GC              NaN
#
#               genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# 183          Sports      4.26      0.26      0.01         0.71          94.0
# ...

# %%
df.dropna(subset=['year_of_release'],inplace=True)

# %%
df['year_of_release'] = df['year_of_release'].astype('int32')

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font> ✔️
#     <br />
#     <font size="3", color = "black">
# <br />Решение верное, перед удалением стоит посмотреть на записи — может они по 100 млн. продаж принесли ...

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Скажи пожалуйста, почему ты считаешь подобный способ заполнения пропусков корректным
#
# ![image.png](attachment:image.png)
#
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Прочитала статью, понимаю свою ошибку. Будут некорректные данные из-за слишком большого разброса. Тогда пропуски оставлю.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />принимается

# %% [markdown]
# *Пропуски в столбце rating *

# %%
df['rating']=df['rating'].fillna('undefined')

# %%
df['rating'].value_counts()
# Out:
# undefined    6676
# E            3924
# T            2905
# M            1536
# E10+         1393
# EC              8
# RP              1
# AO              1
# Name: rating, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Рабочее решение для столбца, который содержит категориальные данные, поможет определить ключевое различие в потрете пользователя
#
#         df['rating'].fillna('undefined',inplace=True)
#
# Пару советов, по какой причине стоит избегать параметр
#
#         inplace=True
#
# https://towardsdatascience.com/why-you-should-probably-never-use-pandas-inplace-true-9f9f211849e4
#
#
#
#
#
# Можно посмотреть на частотность использования категорий рейтинга, по отношению к остальным
#
#         EC         8
#         K-A        3
#         RP         1
#         AO         1
#
#
#
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Этот сайт не даёт мне открыть защита яндекс.браузера, при возможности обязательно прочитаю с другого устройства

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />принимается

# %% [markdown]
# *Округляем оценки до одного знака после запятой*

# %%
df['user_score']=df['user_score'].round(1)

# %%
df['critic_score']=df['critic_score'].round(1)

# %%
df.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8461
# user_score         8981
# rating                0
# dtype: int64

# %% [markdown]
# *Все пропуски обработаны*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16444 non-null  object
#  1   platform         16444 non-null  object
#  2   year_of_release  16444 non-null  int32
#  3   genre            16444 non-null  object
#  4   na_sales         16444 non-null  float64
#  5   eu_sales         16444 non-null  float64
#  6   jp_sales         16444 non-null  float64
#  7   other_sales      16444 non-null  float64
#  8   critic_score     7983 non-null   float64
#  9   user_score       7463 non-null   float64
#  10  rating           16444 non-null  object
# dtypes: float64(6), int32(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# ####  Удаление дубликатов по ключевым столбцам

# %%
df[df.duplicated(subset=['name', 'platform', 'year_of_release'])]
# Out:
#                 name platform  year_of_release   genre  na_sales  eu_sales  \
# 16230  Madden NFL 13      PS3             2012  Sports       0.0      0.01
#
#        jp_sales  other_sales  critic_score  user_score rating
# 16230       0.0          0.0          83.0         5.5      E

# %%
df.duplicated(subset=['name', 'platform', 'year_of_release']).sum()
# Out:
# 1

# %%
df.drop_duplicates(subset=['name', 'platform', 'year_of_release'],inplace=True)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Решение верное, перед удалением стоит посмотреть на записи

# %% [markdown]
# ####  Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.

# %%
df['total_sales'] = df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df['other_sales']
#или можно использовать такой код
#df['total_sales'] = df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score     rating  \
# 0     28.96      3.77         8.45          76.0         8.0          E
# 1      3.58      6.81         0.77           NaN         NaN  undefined
# 2     12.76      3.79         3.29          82.0         8.3          E
# 3     10.93      3.28         2.95          80.0         8.0          E
# 4      8.89     10.22         1.00           NaN         NaN  undefined
#
#    total_sales
# 0        82.54
# 1        40.24
# ...

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font> ✔️
# <br />
# <font size="3", color = "black">
# <br />
# можно
#
#     df['total_sales'] = df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %% [markdown]
# **Вывод:**
#
# Привели названия столбцов к нижнему регистру, заменили типы данных в некоторых стобцах и объяснили почему.
# Обработали значения tbd и неявные дубликаты.
# Обработали пропуски, при возможности заполнили их. Всего удалили 271 пропуск.
# Добавили столбец с суммарными продажами.

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# #### Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
df.groupby('year_of_release')['name'].count()
# Out:
# year_of_release
# 1980       9
# 1981      46
# 1982      36
# 1983      17
# 1984      14
# 1985      14
# 1986      21
# 1987      16
# 1988      15
# 1989      17
# 1990      16
# 1991      41
# 1992      43
# 1993      60
# 1994     121
# 1995     219
# 1996     263
# 1997     289
# 1998     379
# 1999     338
# 2000     350
# 2001     482
# 2002     829
# 2003     775
# 2004     762
# 2005     939
# 2006    1006
# 2007    1197
# 2008    1427
# 2009    1426
# 2010    1255
# 2011    1136
# 2012     652
# 2013     544
# 2014     581
# 2015     606
# 2016     502
# Name: name, dtype: int64

# %%
df.groupby(by='year_of_release')['name'].count().plot(kind='bar', ylabel = 'count',figsize=(10, 7), ec='black')
plt.title('Частота выпуска игр по годам')
plt.xlabel('Год выпуска')
plt.ylabel('Количество игр')
plt.show()

# %% [markdown]
# *По данной гистограмме можно увидеть, что до 1993 года игры почти не выпускались, затем частота выпуска стала рости до 2009 года, затем пошла на спад. С 2012 по 2016 количество выпускаемых за год игр примерно одинаково. Пиком активности выпусков стали 2008-2009 г.*

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Классный график, все элементы добавлены, молодец

# %% [markdown]
# #### Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?

# %%
(df.pivot_table(index='platform',values=['total_sales'],aggfunc=('sum'))
    .sort_values(by='total_sales',ascending=True)
    .plot(kind='barh', figsize=(10, 7), ec='black'))

plt.title('Продажи по платформам')
plt.xlabel('Количество продаж')
plt.ylabel('Платформа')
plt.show()

# %% [markdown]
# *Данных о платформах PCFX, GG, 3DO и TG16 крайне мало, поэтому для более красивых графиков я хочу исключить их из исследования*

# %%
df=df.query('platform !=("PCFX","GG","3DO","TG16")')

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.pivot_table(index="platform",columns='year_of_release',values='total_sales',aggfunc=('sum')))

plt.title('Продажи по платформам')
plt.xlabel('Год продажи')
plt.ylabel('Платформа')
plt.show()

# %% [markdown]
# *Создадим отдельный датафрейм со списком платформ с наибольшими продажами PS2,X360,PS3,Wii,DS,PS и посмотрим на тепловой карте их продажи*

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.pivot_table(index="platform",columns='year_of_release',values='total_sales',aggfunc=('sum'))
            .query('platform ==("PS2","X360","PS3","Wii","DS","PS")'))

plt.title('Продажи популярных платформ')
plt.xlabel('Год продажи')
plt.ylabel('Платформа')
plt.show()

# %% [markdown]
# *Период за который исчезают и появляются новые платформы 10-12 лет. Новые платыормы появляются когда на других популярных плтформах количество продаж начинает идти на спад, то есть они начинают терять свою актуальность. Странный выброс платформы DS в 1985 году, сама платформа была выпущена в 2004 удалим такое значение*

# %%
dr = df.query('platform == "DS" and year_of_release<2004')
df.drop(index=dr.index,inplace=True)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Отличное определение жизненного цикла продаж у платформ, молодец

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font> ✔️
#     <br />
#     <font size="3", color = "black">
# <br />
# Странный выброс 1985 года у DS, можно посмотреть когда платформу выпустили на рынок, стоит удалить аномалию

# %% [markdown]
# #### Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
# Не учитывайте в работе данные за предыдущие годы. Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.

# %% [markdown]
# *Выберем актуальным периодом выпуск с 2014 года, в это время колличество выпускаемых игр стало примерно одинаковым и интервал времени не такой большой благодоря чему исследование пройдет точно. Так же по хитмапу "Продажи по платформам" можно увидеть, что платформа PSP перестала быть актуальной в 2014 году, исключим её.*

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font> ✔️
#     <br />
#     <font size="3", color = "black">
# <br />Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. Но и слишком короткий период тоже брать не стоит
#
#         actual_period=df.query('year_of_release >= 2012 and platform != ("PSP","DS")')

# %%
actual_period=df.query('year_of_release >= 2014 and platform != "PSP"')
actual_period.groupby('platform')['total_sales'].sum().sort_values(ascending=False).plot(figsize=(10,7),kind='bar',ec='black')
plt.title('Продажи с 2014 года')
plt.xlabel('Платформа')
plt.ylabel('Количество продаж')
plt.show()

# %%
plt.figure(figsize=(10,7))
sns.heatmap(actual_period.pivot_table(index="platform",columns='year_of_release',values='total_sales',aggfunc=('sum')))
plt.title('Продажи с 2014 года')
plt.ylabel('Платформа')
plt.xlabel('Год продаж')
plt.show()

# %% [markdown]
# *Лидируют по продажам: PS4, PS3, X360*
#
# *Идут на спад к концу 2016 года: 3DS, PS3, Wii, WiiU, X360*
#
# *Потенциально прибыльные(перспективные): PS4, XOne, PC, 3DS*

# %% [markdown]
# <div class="alert alert-dange r">
# <font size="4"><b>❌ Комментарий ревьюера</b></font> ✔️
#     <br />
#     <font size="3", color = "black">
# <br />Стоит дополнить перечень перспективных платформ
#
#
# даже  на падающих продажах можно заработать, когда объем составляет около 15-20 млн. копий, как например с 3DS

# %% [markdown]
# #### Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.

# %% [markdown]
# *Создадим датафрейм где собраны все платформы платформы для актуального периода*

# %%
plt.figure(figsize=(10, 7))
plt.title('Ящик с усами по глобальным продажам')
sns.boxplot(y='total_sales', x='platform', data=actual_period)
plt.ylabel('Продажи')
plt.xlabel('Платформа')
plt.grid(True)

# %% [markdown]
# *Создадим датафрейм где собраны самые актуальные платформы для актуального периода*

# %%
actual_pl=actual_period.query('platform == ("PS4", "XOne", "3DS", "PC","PS3")')

plt.figure(figsize=(10, 7))
plt.title('Ящик с усами по глобальным продажам')
sns.boxplot(y='total_sales', x='platform', data=actual_pl)
plt.ylabel('Продажи')
plt.xlabel('Платформа')
plt.grid(True)

# %%
actual_pl=actual_period.query('platform == ("PS4", "XOne", "3DS", "PC","PS3")')

plt.figure(figsize=(10, 7))
plt.ylim(-0.1, 2)
plt.title('Ящик с усами по глобальным продажам')
sns.boxplot(y='total_sales', x='platform', data=actual_pl)
plt.ylabel('Продажи')
plt.xlabel('Платформа')
plt.grid(True)

# %% [markdown]
# *Посмотрев на ящик с усами, сожно сделать вывод, что они похожи у популярных платформ. Медиана у платформ с наибольшими продажами выше остальных, так же выше разброс т.к продаж у этих плтформ больше. Максимальные продажи были у PS4*

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Не стоит ограничивать выборку только пятью платформами, так мы лишаемся возможности для оценки ситуации на рынке в целом
#
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Создала отдельный график

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Что показывают нам две диаграммы размаха — кол-во выбросов, это игры, которые принесли максимум выручки. Т.е. можно платформы/жанры сравнить по кол-ву игр-рекордсменов, а значит определить, какая из них способна выпустить наиболее привлекательные для игроманов игры. Это про выбросы
#
# Второй вид мы используем для того, чтобы сравнить медианные продажи по платформе/жанру, чтобы уточнить в каком кол-ве продаются игры на платформе/жанре, какая из них более стабильна в продажах...
#
#
# Две хорошие статьи про диаграмму размаха
#
# [Ящики, усы и скрипки](https://habr.com/ru/articles/533726/)
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font> ✔️
#     <br />
#     <font size="3", color = "black">
# <br />Отлично, ты используешь диаграмму размаха для определения успешности платформы, молодец
#
# Для более полной оценки продаж на платформах стоит добавить график со 100% масштабом, посмотреть на максимальные продажи

# %% [markdown]
# #### Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
# Соотнесите выводы с продажами игр на других платформах.

# %% [markdown]
# **Выберем в качемстве популярной платформы PS4, построим график и найдем кореляию для нее**

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font> ✔️
#     <br />
#     <font size="3", color = "black">
# <br />
# Для красоты («продаваемости») всего проекта не стоит выходить за видимую ширину тетради юпитер ноутбука, коллеги ценят удобство прочтения кода. Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>. ⬇⬇⬇
#
# </div>

# %%
(actual_period.query('platform=="PS4"').sort_values(by='critic_score',ascending=True)
 .plot(x='critic_score',y='total_sales',kind='scatter', style='o', figsize=(10, 7)))

plt.title('Зависимость продаж от отзывов критиков ')
plt.xlabel('Оценка')
plt.ylabel('Продажи')
plt.show()

(actual_period.query('platform=="PS4"').sort_values(by='user_score',ascending=True)
 .plot(x='user_score',y='total_sales',kind='scatter', style='o', figsize=(10, 7)))

plt.title('Зависимость продаж от отзывов пользователей ')
plt.xlabel('Оценка')
plt.ylabel('Продажи')
plt.show()

# %% [markdown]
# *Расчитаем корреляцию*

# %%
print('Зависимость продаж от оценки критиков',
      round(actual_period.query('platform=="PS4"')['total_sales'].corr(actual_period.query('platform=="PS4"')['critic_score']),2),'\n',
    'Зависимость продаж от оценки пользователей',
      round(actual_period.query('platform=="PS4"')['total_sales'].corr(actual_period.query('platform=="PS4"')['user_score']),2))
# Out:
# Зависимость продаж от оценки критиков 0.4
#  Зависимость продаж от оценки пользователей -0.04

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font> ✔️
#     <br />
#     <font size="3", color = "black">
# <br /> на проектах стоит снижать размерность выводимой информации, где не требуется максимальная точность, до одного или двух знаков после запятой
#
#             Зависимость стоимости от оценки критиков 0.34887240172175027
#              Зависимость стоимости от оценки пользователей -0.04415647112602573

# %% [markdown]
# **Найдем корреляюцию и построим диаграммы для еще двух популярных платформ**

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font> ✔️
#     <br />
#     <font size="3", color = "black">
# <br />Стоит добавить парочку диаграмм рассеяния, коэф. корреляции отображает лишь возможное наличие линейной связи

# %% [markdown]
# *Для платформы XOne*

# %%
(actual_period.query('platform=="XOne"').sort_values(by='critic_score',ascending=True)
 .plot(x='critic_score',y='total_sales',kind='scatter', style='o', figsize=(10, 7)))

plt.title('Зависимость продаж от отзывов критиков ')
plt.xlabel('Оценка')
plt.ylabel('Продажи')
plt.show()

(actual_period.query('platform=="XOne"').sort_values(by='user_score',ascending=True)
 .plot(x='user_score',y='total_sales',kind='scatter', style='o', figsize=(10, 7)))

plt.title('Зависимость продаж от отзывов пользователей ')
plt.xlabel('Оценка')
plt.ylabel('Продажи')
plt.show()

print('Зависимость продаж от оценки критиков',
      round(actual_period.query('platform=="XOne"')['total_sales'].corr(actual_period.query('platform=="XOne"')['critic_score']),2),'\n',
    'Зависимость продаж от оценки пользователей',
      round(actual_period.query('platform=="XOne"')['total_sales'].corr(actual_period.query('platform=="XOne"')['user_score']),2))
# Out:
# Зависимость продаж от оценки критиков 0.43
#  Зависимость продаж от оценки пользователей -0.07

# %% [markdown]
# *Для платформы PS3*

# %%
(actual_period.query('platform=="PS3"').sort_values(by='critic_score',ascending=True)
 .plot(x='critic_score',y='total_sales',kind='scatter', style='o', figsize=(10, 7)))

plt.title('Зависимость продаж от отзывов критиков ')
plt.xlabel('Оценка')
plt.ylabel('Стоимость')
plt.show()

(actual_period.query('platform=="PS3"').sort_values(by='user_score',ascending=True)
 .plot(x='user_score',y='total_sales',kind='scatter', style='o', figsize=(10, 7)))

plt.title('Зависимость продаж от отзывов пользователей ')
plt.xlabel('Оценка')
plt.ylabel('Стоимость')
plt.show()

print('Зависимость продаж от оценки критиков',
      round(actual_period.query('platform=="PS3"')['total_sales'].corr(actual_period.query('platform=="PS3"')['critic_score']),2),'\n',
    'Зависимость продаж от оценки пользователей',
      round(actual_period.query('platform=="PS3"')['total_sales'].corr(actual_period.query('platform=="PS3"')['user_score']),2))
# Out:
# Зависимость продаж от оценки критиков 0.45
#  Зависимость продаж от оценки пользователей -0.17

# %% [markdown]
# *Найдем кореляцию для остальных популярных платформ*

# %%
print('Зависимость продаж 3DS от оценки критиков',
      round(actual_period.query('platform=="3DS"')['total_sales'].corr(actual_period.query('platform=="3DS"')['critic_score']),2),'\n',
    'Зависимость продаж от оценки пользователей',
      round(actual_period.query('platform=="3DS"')['total_sales'].corr(actual_period.query('platform=="3DS"')['user_score']),2))

print('Зависимость продаж PC от оценки критиков',
      round(actual_period.query('platform=="PC"')['total_sales'].corr(actual_period.query('platform=="PC"')['critic_score']),2),'\n',
    'Зависимость продаж от оценки пользователей',
      round(actual_period.query('platform=="PC"')['total_sales'].corr(actual_period.query('platform=="PC"')['user_score']),2))
# Out:
# Зависимость продаж 3DS от оценки критиков 0.31
#  Зависимость продаж от оценки пользователей 0.22
# Зависимость продаж PC от оценки критиков 0.17
#  Зависимость продаж от оценки пользователей -0.07

# %% [markdown]
# **Вывод**
#  *Если судить по кореляции, то в большинстве случаев количество продаж не зависит от оценки пользователей(Возможно это связано с тем, что игроки как правило относятся к играм более критично). Зависимость продаж от оценки критиков присутсвует, но слабая. Но корреляция не всегда говорит о зависимости, мы не можем утверждать, что высокие оценки критиков приводят к высоким продажам игр.*

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font> ✔️
#     <br />
#     <font size="3", color = "black">
# <br />Возможно пользователи более критичны к играм, чем критики, но мы не сможем оценить какие действия повлияли на рост продаж в рамках нашего проекта (ограниченность имеющихся данных)
#
#
# __Достаточно много игр с высокой оценкой критиков и слабой выручкой__
#
# Приведу пример ложной корреляции, весьма известный в статистической литературе. Была исследована корреляционная связь между числом аистов, свивших гнезда в южных районах Швеции, и рождаемостью в эти же годы в Швеции. Расчёты, выполненные ради шутки, показали существенную положительную корреляцию между этими явлениями, хотя любому понятно, что это ложная корреляция.
#
# Ещё пример ложной корреляции между приемом на работу новых менеджеров и созданием новых производственных мощностей. Возможно, именно менеджеры являются «причиной» капиталовложений в новые производственные мощности? Или же, наоборот, создание новых производственных мощностей послужило «причиной» приема на работу новых менеджеров?
#
# Например, можно обнаружить сильную положительную связь (корреляцию) между разрушениями, вызванными пожаром, и числом пожарных, тушивших пожар. Следует ли заключить, что пожарные вызывают разрушения? Конечно, наиболее вероятное объяснение этой корреляции состоит в том, что размер пожара (внешняя переменная, которую забыли включить в исследование) оказывает влияние, как на масштаб разрушений, так и на числе привлеченных пожарных (т. е. чем больше пожар, тем большее количество пожарных вызывается на его тушение) .

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font> ✔️
#     <br />
#     <font size="3", color = "black">
# <br />
# При подобной величине коэффициента не важно какой у него знак, плюс или минус
#
#         В большинстве случаев количество продаж не зависит от оценки пользователей, чаще корреляция отрицательна.
#
#         Зависимость продаж XOne от оценки пользователей: -0.08838163832202786
#
#
# [Шкала Чедока. Объяснит отличие слабой корреляции от умеренной и высокой.](https://ekonometrik.ru/%D1%88%D0%BA%D0%B0%D0%BB%D0%B0-%D1%87%D0%B5%D0%B4%D0%B4%D0%BE%D0%BA%D0%B0/)

# %% [markdown]
# #### Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %%
plt.figure(figsize=(15, 12))
sns.boxplot(y='total_sales', x='genre', data=actual_period)
plt.title('Распределение по жанрам')
plt.ylabel('Продажи')
plt.xlabel('Жанр')
plt.grid(True)

# %%
plt.figure(figsize=(15, 12))
sns.boxplot(y='total_sales', x='genre', data=actual_period)
plt.ylim(0, 4)
plt.title('Распределение по жанрам')
plt.ylabel('Продажи')
plt.xlabel('Жанр')
plt.grid(True)

# %%
actual_period.groupby('genre').median()['total_sales'].sort_values(ascending=False)
# Out:
# genre
# Shooter         0.515
# Sports          0.190
# Platform        0.140
# Fighting        0.125
# Role-Playing    0.110
# Simulation      0.100
# Action          0.090
# Misc            0.090
# Racing          0.090
# Strategy        0.060
# Puzzle          0.045
# Adventure       0.030
# Name: total_sales, dtype: float64

# %% [markdown]
# **Вывод:**
# Можно сделать вывод что наиболее прибыльными являются такие жанры как: шутер, платформер и спортивный
# Самыми малопродаваемымм являются жанры приключений и пазлы, их мединное значение значительно ниже других.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит проанализировать прибыльность жанров на диаграмме размаха, сравнить медианные продажи на каждом жанре и проверить какая из них более стабильна и имеет более длинный ряд успешно продающихся игр
#
# График нарисовать __в двух масштабах с выбросами и без__ (чтобы было видно 0.75-квантиль)
#
# Скажи пожалуйста о чем этот вывод?
#
#         Можно заметить что нет прямой зависимости жанра игры с ее выпуском и прибылью. То есть наиболее прибыльные жанры не выпускаются так часто, а игры с небольшшой прибылью выпускаются чаще. Возможно разработка таких жанров стоит не так дорого и не так сложно
#
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Скорее всего я хотела сказать что жанры игр, которые выпускаются чаще остальных не имеют большой прибыли. А жанры игр которые имеют большую прибыль среди остальных выпускаются реже. И пыталась объяснить с чем это может быть связано. Теперь перечитав понимаю, что намудрила непонятностей 😅

# %% [markdown]
# ### Составьте портрет пользователя каждого региона
# Определите для пользователя каждого региона (NA, EU, JP):
#
# Самые популярные платформы (топ-5). Опишите различия в долях продаж.
#
# Самые популярные жанры (топ-5). Поясните разницу.
#
# Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %% [markdown]
# #### Регион NA

# %%
region = 'na_sales'
columns = ('platform', 'genre', 'rating')
fig, axs = plt.subplots(1, 3)

for num, column in enumerate(columns):
    (actual_period.pivot_table(index=column, values=region, aggfunc='sum')
     .sort_values(region, ascending=False).head(5)
      .plot(kind="pie", y=region, ax=axs[num], figsize=(20,20), ylabel='', title=column, legend=False, autopct='%1.0f%%',colors = sns.color_palette('pastel'))
    )
plt.show()

# %% [markdown]
# * *Наиболее популярны PS4 39% и XOne 32% по сравнению с остальными платформами*
# * *Самые популярные жанры Экшен 29% и Шутер 32%*
# * *Самый популярный рейтинг игр M (17+) 34%

# %% [markdown]
# #### Регион EU

# %%
region = 'eu_sales'
fig, axs = plt.subplots(1, 3)

for num, column in enumerate(columns):
    (actual_period.pivot_table(index=column, values=region, aggfunc='sum')
     .sort_values(region, ascending=False).head(5)
      .plot(kind="pie", y=region, ax=axs[num], figsize=(15,15), ylabel='', title=column, legend=False, autopct='%1.0f%%',colors = sns.color_palette('flare'))
    )
plt.show()

# %% [markdown]
# * *Наиболее популярна PS4 55% по сравнению с остальными платформами *
# * *Самые популярные жанры Экшен 33% и Шутер 29%*
# * *Самый популярный рейтинг игр M (17+) 35%
#
# Регионы EU и NA очень похожи между собой.

# %% [markdown]
# #### Регион JP

# %%
region = 'jp_sales'
fig, axs = plt.subplots(1, 3)

for num, column in enumerate(columns):
    (actual_period.pivot_table(index=column, values=region, aggfunc='sum')
     .sort_values(region, ascending=False).head(5)
      .plot(kind="pie", y=region, ax=axs[num], figsize=(15,15), ylabel='', title=column, legend=False, autopct='%1.0f%%',colors = sns.color_palette('Set2'))
    )
plt.show()

# %% [markdown]
# * *Наиболее популярна 3DS 48% по сравнению с остальными платформами *
# * *Самые популярные жанры Ролевые 40% и Экшен 38%*
# * *Самый популярный рейтинг игр неопределённый (для взрослой аудитории) 61%

# %% [markdown]
# #### Сделаем выборки по другим продажам

# %% [markdown]
# **Выборка для платформ NA**

# %%
na=actual_period.pivot_table(index='platform',values=['na_sales'],aggfunc=('sum'))
na=na.sort_values(by='na_sales',ascending=False)
na=na.reset_index()
na1=na.head(5)
other=na['na_sales'][5:].sum()
na=na1.append({'platform': 'Other', 'na_sales': other}, ignore_index = True)
na
# Out:
#   platform  na_sales
# 0      PS4     98.61
# 1     XOne     81.27
# 2     X360     28.30
# 3      3DS     22.64
# 4      PS3     22.05
# 5    Other     31.19

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит поправить расчет категории
#
#         5	Other	252.87
#
# В реальности у нас сумма остальных продаж на остальных платформах равна
#
#         31.19

# %% [markdown]
# **Выборка для платформ EU**

# %%
eu=actual_period.pivot_table(index='platform',values=['eu_sales'],aggfunc=('sum'))
eu=eu.sort_values(by='eu_sales',ascending=False)
eu=eu.reset_index()
eu1=eu.head(5)
other=eu['eu_sales'][5:].sum()
eu=eu1.append({'platform': 'Other', 'eu_sales': other}, ignore_index = True)
eu
# Out:
#   platform  eu_sales
# 0      PS4    130.04
# 1     XOne     46.25
# 2      PS3     25.54
# 3       PC     17.97
# 4      3DS     16.12
# 5    Other     34.76

# %% [markdown]
# **Выборка для платформ JP**

# %%
jp=actual_period.pivot_table(index='platform',values=['jp_sales'],aggfunc=('sum'))
jp=jp.sort_values(by='jp_sales',ascending=False)
jp=jp.reset_index()
jp1=jp.head(5)
other=jp['jp_sales'][5:].sum()
jp=jp1.append({'platform': 'Other', 'jp_sales': other}, ignore_index = True)
jp
# Out:
#   platform  jp_sales
# 0      3DS     44.24
# 1      PS4     15.02
# 2      PSV     14.54
# 3      PS3     11.22
# 4     WiiU      7.31
# 5    Other      0.40

# %% [markdown]
# **Выборка для жанров NA**

# %%
na=actual_period.pivot_table(index='genre',values=['na_sales'],aggfunc=('sum'))
na=na.sort_values(by='na_sales',ascending=False)
na=na.reset_index()
na1=na.head(5)
other=na['na_sales'][5:].sum()
na=na1.append({'genre': 'Other', 'na_sales': other}, ignore_index = True)
na
# Out:
#           genre  na_sales
# 0       Shooter     79.02
# 1        Action     72.53
# 2        Sports     46.13
# 3  Role-Playing     33.47
# 4          Misc     15.05
# 5         Other     37.86

# %% [markdown]
# **Выборка для жанров EU**

# %%
eu=actual_period.pivot_table(index='genre',values=['eu_sales'],aggfunc=('sum'))
eu=eu.sort_values(by='eu_sales',ascending=False)
eu=eu.reset_index()
eu1=eu.head(5)
other=eu['eu_sales'][5:].sum()
eu=eu1.append({'genre': 'Other', 'eu_sales': other}, ignore_index = True)
eu
# Out:
#           genre  eu_sales
# 0        Action     74.68
# 1       Shooter     65.52
# 2        Sports     45.73
# 3  Role-Playing     28.17
# 4        Racing     14.13
# 5         Other     42.45

# %% [markdown]
# **Выборка для жанров JP**

# %%
jp=actual_period.pivot_table(index='genre',values=['jp_sales'],aggfunc=('sum'))
jp=jp.sort_values(by='jp_sales',ascending=False)
jp=jp.reset_index()
jp1=jp.head(5)
other=jp['jp_sales'][5:].sum()
jp=jp1.append({'genre': 'Other', 'jp_sales': jp['jp_sales'][5:].sum()}, ignore_index = True)
jp
# Out:
#           genre  jp_sales
# 0  Role-Playing     31.16
# 1        Action     29.38
# 2      Fighting      6.37
# 3          Misc      5.59
# 4       Shooter      4.87
# 5         Other     15.36

# %% [markdown]
# *Выборка для рейтинга*

# %%
na=actual_period.pivot_table(index='rating',values=['na_sales'],aggfunc=('sum'))
eu=actual_period.pivot_table(index='rating',values=['eu_sales'],aggfunc=('sum'))
jp=actual_period.pivot_table(index='rating',values=['jp_sales'],aggfunc=('sum'))
rat=na.merge(eu, on='rating')
rat=rat.merge(jp, on='rating')
rat
# Out:
#            na_sales  eu_sales  jp_sales
# rating
# E             50.74     58.06      8.94
# E10+          33.23     26.16      4.46
# M             96.42     93.44      8.01
# T             38.95     34.07     14.78
# undefined     64.72     58.95     56.54

# %% [markdown]
# **Вывод:**
# * **Портрет пользователя Северной Америки:** Играет в шутер или экшен с рейтингом M, используя для этого платформу или PS4 или XOne.
# * **Портрет пользователя Европы:** Играет в Шутер или Экшен с рейтингом M, используя при этом платформу PS4.
# * **Портрет пользователя Японии:** Играет или в ролевые игры или в экшен, с возврастным рейтингом не для детей, используя при этом портативную платформу 3DS.

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Портреты клиентов нарисованы, молодец, влияние на портрет оказывает период с 2012 г. ..., можем совершить ошибку при формировании рекомендации маркетологам
#
# Стоит оформить графики раздела TOП-5:
#
# + выбрать актуальный период;
# + для каждого ТОП-5 - построить 3 графика рядом с помощью subplots, оптимальнее сравнивать три региона по каждому виду портрета вместе;
# + оформить "двухуровневый заголовок" - и у всех трех графиков вместе, и у каждого из трех по отдельности;
# + при анализе платформ и жанров стоит все, что не вошло в ТОП-5, объединять в категорию "другие" - так картина анализа будет более полной
#
#
# Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе
#
# https://proproprogs.ru/modules/matplotlib-otobrazhenie-neskolkih-koordinatnyh-osey-v-odnom-okne
#
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Не понимаю как сохранить названия индесов

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Круговая диаграмма из ТОП-5 искажает доли рынка, которые занимают первые топ-5 платформ, т.к. их сумма продаж делится на 100%, но у нас имеются другие платформы, которые также занимают определенную долю рынка

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Предлагаю попробовать создать шестую категорию — «Другие» и объединить туда все не вошедшие в ТОП-5 строчки
#
# Добавил пример создания строки (у меня он развернут в обратном порядке)
#
#
# На данном этапе интересует сама выборка ТОП-5 плюс категория «Другие», без графиков

# %%
# check
# import pandas as pd
df_app = pd.DataFrame([['ps',1,2,3],
                   ['xone',3,5,6],
                   ['pc',8,9,10],
                   ['ps3',1,7,3],
                   ['ps4',5,2,3]], columns=['platform', 'eu','jp','na'])
display(df_app)

df_other = df_app[3:]
df_other = df_other.append({'platform': 'Other', 'eu': df_app['eu'].sum()-df_app['eu'][3:].sum(),
                  'jp': df_app['jp'].sum()-df_app['jp'][3:].sum(),
                  'na': df_app['na'].sum()-df_app['na'][3:].sum()}, ignore_index = True)
df_other
# Out:
#   platform  eu  jp  na
# 0       ps   1   2   3
# 1     xone   3   5   6
# 2       pc   8   9  10
# 3      ps3   1   7   3
# 4      ps4   5   2   3
#   platform  eu  jp  na
# 0      ps3   1   7   3
# 1      ps4   5   2   3
# 2    Other  12  16  19

# %% [markdown]
# ### check

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Или берем одну выборку ⬇⬇⬇ и создаем из неё выборку с 6-ю строчками.
#
# Это базовый навык работы с таблицей, навык по трансформации — из 10-ти строчек получить 6 в которой первые пять это топовые позиции, а последняя шестая — это сумма всех остальных строк, кроме первых пяти
#
# ![image.png](attachment:image.png)
#
# Если ты не понимаешь, как выполнить это, тогда стоит задать вопрос преподавателю по проектам в чате «пачки». Также ты можешь написать вопрос или пример кода в проекте и опять отправить его на проверку — так я смогу тебе ответить
#
#
# Можно посмотреть на порядок применения loc
#
# https://tonais.ru/library/zamena-odnogo-ili-neskolkih-znacheniy-v-stolbtse-v-dataframe?ysclid=l5jjs9blfj495302948
#
# https://towardsdatascience.com/how-to-use-loc-and-iloc-for-selecting-data-in-pandas-bd09cb4c3d79
#
# Выбор способа создания за тобой

# %%
# check

actual_period.groupby('platform').agg({'na_sales': 'sum'}).sort_values(by='na_sales', ascending=False)
# Out:
#           na_sales
# platform
# PS4          98.61
# XOne         81.27
# X360         28.30
# 3DS          22.64
# PS3          22.05
# WiiU         19.36
# PC            7.23
# PSV           2.52
# Wii           2.08

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> пример графиков
#
# ![image.png](attachment:image.png)
#
#
# __Если столкнешься с трудностью выполнения данного пункта — присылай код, который не получился и вопрос, подумаем вместе__

# %% [markdown]
# ### Проверка гипотез

# %% [markdown]
# *Для формулирования нулевой гипотезы используется знак равенства, альтернативная складывается из противоположности нулевой(>,< или !=). Для сравнения будем использовать t-test*

# %% [markdown]
# #### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# **Нулевая гипотеза:** Средние пользовательские рейтинги платформ Xbox One и PC равны.
#
# **Альтернативная гипотеза:** Средние пользовательские рейтинги платформ Xbox One и PC не равны.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Гипотезы сформулированы верно

# %%
plt.figure(figsize=(7,4))
sns.heatmap(actual_period.pivot_table(index="platform",columns='year_of_release',values='total_sales',aggfunc=('sum'))
            .query('platform ==("PC","XOne")'))

plt.title('Продажи популярных платформ')
plt.xlabel('Год продажи')
plt.ylabel('Платформа')
plt.show()

# %%
df_user_score = actual_period.dropna(subset=['user_score']).reset_index(drop = True)

Xbox = df_user_score.query('platform == "XOne"')
PC = df_user_score.query('platform == "PC"')

# %% [markdown]
# *Размер периода использования платформ одинаковый *

# %%
results = st.ttest_ind(Xbox.user_score, PC.user_score)
 
alpha = 0.05
 
print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.10450507919348415
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# *Полученное значение p-value говорит о том, что такое или большее различие можно получить случайно с очень маленькой вероятностью (Меньше 6%). Нулевую гипотезу не получилось отвергнуть, а это означает, что средние пользовательские рейтинги платформ Xbox One и PC равны.*

# %%
# xone_us,pc_us

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит избавиться от любых видов заглушек (нулевых, отрицательных, положительных) при расчете стат. тестов
#
# по этой причине у нас в результате
#
#         p-значение: nan

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Важно удалить пропуски и «заглушки» перед проведением теста, молодец

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>✔️
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит выравнивать периоды использования платформ, одна из приставок вышла на рынок совсем недавно ...
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Из-за смены актуального периода, периоды использования стали одинаковыми

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>✔️
#     <br />
#     <font size="3", color = "black">
# <br /> Что означает на языке статистики p-значение: 0.3059935613686402

# %% [markdown]
# #### Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные

# %% [markdown]
# **Нулевая гипотеза:** Средние пользовательские рейтинги жанров Action и Sports равны.
#
# **Альтернативная гипотеза:** Средние пользовательские рейтинги жанров Action и Sports не равны.

# %%
action = df_user_score.query('genre == "Action"')
sports = df_user_score.query('genre == "Sports"')


results = st.ttest_ind(action.user_score, sports.user_score)
 
alpha = 0.05
 
print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 2.8711147985105864e-19
# Отвергаем нулевую гипотезу

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит избавиться от любых видов заглушек (нулевых, отрицательных, положительных) при расчете стат. тестов
#
# по этой причине у нас в результате
#
#         p-значение: nan

# %% [markdown]
# *Нулевая гипотеза отвергнута, а это значит, что средние пользовательские рейтинги жанров Action и Sports не равны.*

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# В ходе исследвания были выполнены и написаны выводы по следующим пунктам:
# 1. Загружены и описаны полученные файлы:
#     * основная информация.
#     * пропущенные значения.
#     * явные и невные дубликаты.
#
# 2. Была проведена предобработка данных:
#     * названия столбцов приведины к нижнему регистру.
#     * данные преобразованы в нужные типы, описаны почему.
#     * обработаны значения tbd.
#     * обработаны неявные дубликаты.
#     * обработаны пропущенные значения, описаны почему.
#     * посчитан и добавлен столбец с суммарными продажами.
#
# 3. Проведён исследовательский анализ данных:
#     * построена гистограмма о том сколько игр выпускалось в разные годы.
#     * посмотрено, как менялись продажи по платформам .
#     * выбраны платформы с наибольшими суммарными продажами и построено распределение по годам.
#     * определено за какой характерный срок появляются новые и исчезают старые платформы. Построен хитмап.
#     * определён актуальный период чтобы построить прогноз на 2017 год.
#     * получены данные о том, какие платформы лидируют по продажам.
#     * построен график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Описан результат.
#     * построена диаграмма рассеяния и поределана кореляция, чтобы понять, как влияют на продажи отзывы пользователей и критиков.
#     * посмотрено общее распределение игр по жанрам.
#
# 4. Составлены портреты пользователей для каждого региона:
#     * определены самые популярные платформы.
#     * определены самые популярные жанры.
#     * определено влияет ли рейтинг на продажи.
#
# 5. Произведена проверка гипотез, описано как формулировались гипотезы и какой способ выбран для проверки.

# %% [markdown]
# **Анализ на 2017 год**
# * Использовать современные платформы. Закупать игры на PS4, XOne и 3DS.
# * Выставлять на видное место игры с популярными жанрами - экшен, шутеры и ролевые.
# * Отслеживать аудиторию покупателей. В основом большинство игр имеют рейтинг 17+.
# * Распространять популярные игры на пк, тк он еще долго будет актуален.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Итоговый вывод технически составлен грамотно, рекомендация бизнесу замечательная, молодец
#
# стоит перепроверить нюансы после  исправления всех комментариев

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Ты выполнила практически все пункты проекта, молодец! Проведен значительный объем исследования
#
# Критические ❌ комментарии связаны с неточностями:
#
#  + заполнение пропусков в колонках оценок
#  + сократить категории в рейтингах ESRB — на твое усмотрение
#  + выполнить проверку на дублирование записей
#  + переопределить актуальный период
#  + дополнить перечень перспективных платформ
#  + оценить прибыльность жанров на диаграмме размаха
#  + перестроить графики в ТОП-5
#  + в разделе проверки гипотез подправить выборки плюс можно более подробно расшифровать значение p_value
#  + перепроверить промежуточные и итоговый выводы после всех исправлений
#
# Стоит обратить внимание на ⚠️ комментарии...
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Может пригодиться
#
# [Подборка статей о работе с библиотеками для анализа данных на языке Python](https://dfedorov.spb.ru/pandas/)
#
#
# [Визуализация](https://dfedorov.spb.ru/pandas/%D0%AD%D1%84%D1%84%D0%B5%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D0%BE%D0%B5%20%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20Matplotlib.html)
#
#
# [Искусство статистики](https://www.mann-ivanov-ferber.ru/books/iskusstvo-statistiki/)
#
# [Постер «Графики, которые убеждают всех»](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)
#
#
# В помощь — как реализовать интерактивный план проекта вручную (для собственных проектов), смотри по <a href="https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704">ссылке</a>
#
# пара ссылок и по разделам проекта можно будет переходить без пролистывания всего кода, особенно актуально на проектах длина которых >  10 страниц (и там где не установлен плагин TOC)

# %% [markdown]
# ### Бонус

# %%
data_games = pd.read_csv('/datasets/games.csv')

# %%
data_games.columns = map(str.lower, data_games.columns)

# %%
data_games = data_games.dropna(subset = ['year_of_release', 'name', 'genre'])

# %%
data_games['user_score'] = data_games['user_score'].replace('tbd', np.nan).astype('float')

# %%
data_games['rating'] = data_games['rating'].fillna('unknown')

# %%
data_games['total_sales'] = data_games[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %%
# check
# круги + категория другие
def graph (df, year, region, name, axes):
    
    df = df.query('year_of_release >= @year')
    
    sales = df.pivot_table(index='platform', 
                           values=region, 
                           aggfunc='sum').nlargest(5, region)
    
    sales = sales.reset_index()
    
    sales = (
            sales.append({'platform': 'Other', region: df[region].sum() 
                       - sales[region].sum()}, ignore_index= True)
         )
    
    
    sales.columns = ['platform', 'sales']
      
    labels_c=sales.platform
    colours = {'Wii':'C0', 'NES':'C1', 'GB':'C2', 'DS':'C3', 'X360':'C4', 
    'PS3':'C5', 'PS2':'C6', 'SNES':'C7', 'GBA':'C8',
               'PS4':'steelblue', '3DS':'orange', 
               'N64':'C11', 'PS':'C12', 'XB':'C13', 'PC':'C14', '2600':'C15', 'PSP':'C16', 
               'XOne':'C17',
               'WiiU':'C18', 'GC':'C19', 'GEN':'C20', 'DC':'C21', 'PSV':'C22', 
               'SAT':'C23', 'SCD':'C24', 'WS':'C25', 'NG':'C26', 
               'TG16':'C27', '3DO':'C28', 'GG':'C29', 'PCFX':'C30', 'Other':'darkred'}
   
    sales.plot(kind='pie',
               y="sales",
               
               autopct='%1.0f%%',
               wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
               textprops={'size': 'x-large'}, 
               labels= labels_c,
               colors=[colours[key] for key in labels_c],
               legend=False, 
               title = f"Популярность платформ в {name} ", 
               ax = axes).set(ylabel='')
    
    plt.tight_layout()

# %%
# check
# круги в ряд

x_year = 2012

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Оптимальный период для исследования 2014-2016 гг., т.к. данные за 2016 г. неполные

# %%
# check
# круги в ряд

x_year = 2014

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в4</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> 2015 год взят для акцентирования на изменении доли в продажах современных платформ

# %%
# check
# круги в ряд

x_year = 2015

fig, axes = plt.subplots(1, 3, figsize = (15,6))
fig.suptitle(f'Обзор рынка платформ (портрет покупателя) с {x_year} г.', fontsize = 24, fontweight='bold')

graph(data_games, x_year, 'na_sales', 'Северной Америке', axes[0])
graph(data_games, x_year,'eu_sales', 'Европе', axes[1])
graph(data_games, x_year, 'jp_sales', 'Японии', axes[2])
